# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('budget_data.csv')

#Initialize an emptylist object to hold the contents of budget_data.csv
budgets = []

# Initialize line_num variable
revenue = 0
previous_revenue = 0
total_months = 0
average_months = 0
total_revenue = 0
profit_change = 0
total_change = 0 
average_change = 0
greatest_increase = 0
greatest_decrease = 0


# Use a with statement and open the budget_data.csv by using its file path. 
#Use the reader function from the csv library to begin reading budget_data.csv
with open(csvpath, 'r') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',')
#Use the next function to skip the header (first row of the CSV).
        csv_header = next(csvreader)
        csv_header.append("Profit Change")
        budgets.append(csv_header)
               
# Read each row of data after the header.  Add a column for the previous profit and change in profit from one month to the next.  
        for row in csvreader:
            month = row[0]
            revenue = int(row[1])
            row.append(previous_revenue)
            budgets.append(row)
            if previous_revenue == 0:  
                previous_revenue = revenue
            previous_revenue += profit_change
            profit_change = revenue - previous_revenue
            total_revenue += revenue
            row.append(profit_change)
            budgets.append(row)
            
#Figure out the minimum and manximum profit change 
            
            if profit_change >= greatest_increase:
                greatest_increase = profit_change
                increase_month = month
     
            if profit_change <= greatest_decrease:
                greatest_decrease = profit_change
                decrease_month = month 
                
#calculate the total months and total change in profit 
            total_months += 1
            total_change += profit_change 
            print(row)
           
    
#figure out the average change in profit 
average_months = total_months - 1        
average_change = round((total_change / average_months), 2)

print()        
print("Financial Analysis")
print("--------------------------")
print(f"Total Months: {total_months}")
print(f"Total: ${total_revenue}")
print(f"Average Change: ${average_change}")  
print(f"Greatest Increase in Profits: {increase_month} (${greatest_increase})")
print(f"Greatest Decrease in Profits: {decrease_month} (${greatest_decrease})")
# Out:
# ['Jan-2010', '867884', 0, 0]
# ['Feb-2010', '984655', 867884, 116771]
# ['Mar-2010', '322013', 867884, -662642]
# ['Apr-2010', '-69417', 984655, -391430]
# ['May-2010', '310503', 322013, 379920]
# ['Jun-2010', '522857', -69417, 212354]
# ['Jul-2010', '1033096', 310503, 510239]
# ['Aug-2010', '604885', 522857, -428211]
# ['Sep-2010', '-216386', 1033096, -821271]
# ['Oct-2010', '477532', 604885, 693918]
# ['Nov-2010', '893810', -216386, 416278]
# ['Dec-2010', '-80353', 477532, -974163]
# ['Jan-2011', '779806', 893810, 860159]
# ['Feb-2011', '-335203', -80353, -1115009]
# ['Mar-2011', '697845', 779806, 1033048]
# ['Apr-2011', '793163', -335203, 95318]
# ['May-2011', '485070', 697845, -308093]
# ['Jun-2011', '584122', 793163, 99052]
# ['Jul-2011', '62729', 485070, -521393]
# ['Aug-2011', '668179', 584122, 605450]
# ['Sep-2011', '899906', 62729, 231727]
# ['Oct-2011', '834719', 668179, -65187]
# ['Nov-2011', '132003', 899906, -702716]
# ['Dec-2011', '309978', 834719, 177975]
# ['Jan-2012', '-755566', 132003, -1065544]
# ['Feb-2012', '1170593', 309978, 1926159]
# ['Mar-2012', '252788', -755566, -917805]
# ['Apr-2012', '1151518', 1170593, 898730]
# ['May-2012', '817256', 252788, -334262]
# ['Jun-2012', '570757', 1151518, -246499]
# ['Jul-2012', '506702', 817256, -64055]
# ['Aug-2012', '-1022534', 570757, -1529236]
# ['Sep-2012', '475062', 506702, 1497596]
# ['Oct-2012', '779976', -1022534, 304914]
# ['Nov-2012', '144175', 475062, -635801]
# ['Dec-2012', '542494', 779976, 398319]
# ['Jan-2013', '359333', 144175, -183161]
# ['Feb-2013', '321469', 542494, -37864]
# ['Mar-2013', '67780', 359333, -253689]
# ['Apr-2013', '471435', 321469, 403655]
# ['May-2013', '565603', 67780, 94168]
# ['Jun-2013', '872480', 471435, 306877]
# ['Jul-2013', '789480', 565603, -83000]
# ['Aug-2013', '999942', 872480, 210462]
# ['Sep-2013', '-1196225', 789480, -2196167]
# ['Oct-2013', '268997', 999942, 1465222]
# ['Nov-2013', '-687986', -1196225, -956983]
# ['Dec-2013', '1150461', 268997, 1838447]
# ['Jan-2014', '682458', -687986, -468003]
# ['Feb-2014', '617856', 1150461, -64602]
# ['Mar-2014', '824098', 682458, 206242]
# ['Apr-2014', '581943', 617856, -242155]
# ['May-2014', '132864', 824098, -449079]
# ['Jun-2014', '448062', 581943, 315198]
# ['Jul-2014', '689161', 132864, 241099]
# ['Aug-2014', '800701', 448062, 111540]
# ['Sep-2014', '1166643', 689161, 365942]
# ['Oct-2014', '947333', 800701, -219310]
# ['Nov-2014', '578668', 1166643, -368665]
# ['Dec-2014', '988505', 947333, 409837]
# ['Jan-2015', '1139715', 578668, 151210]
# ['Feb-2015', '1029471', 988505, -110244]
# ['Mar-2015', '687533', 1139715, -341938]
# ['Apr-2015', '-524626', 1029471, -1212159]
# ['May-2015', '158620', 687533, 683246]
# ['Jun-2015', '87795', -524626, -70825]
# ['Jul-2015', '423389', 158620, 335594]
# ['Aug-2015', '840723', 87795, 417334]
# ['Sep-2015', '568529', 423389, -272194]
# ['Oct-2015', '332067', 840723, -236462]
# ['Nov-2015', '989499', 568529, 657432]
# ['Dec-2015', '778237', 332067, -211262]
# ['Jan-2016', '650000', 989499, -128237]
# ['Feb-2016', '-1100387', 778237, -1750387]
# ['Mar-2016', '-174946', 650000, 925441]
# ['Apr-2016', '757143', -1100387, 932089]
# ['May-2016', '445709', -174946, -311434]
# ['Jun-2016', '712961', 757143, 267252]
# ['Jul-2016', '-1163797', 445709, -1876758]
# ['Aug-2016', '569899', 712961, 1733696]
# ['Sep-2016', '768450', -1163797, 198551]
# ['Oct-2016', '102685', 569899, -665765]
# ['Nov-2016', '795914', 768450, 693229]
# ['Dec-2016', '60988', 102685, -734926]
# ['Jan-2017', '138230', 795914, 77242]
# ['Feb-2017', '671099', 60988, 532869]
#
# Financial Analysis
# --------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Profits: Sep-2013 ($-2196167)
